# %%
library(tidyverse)
library(dplyr)
library(tidymodels)

# %%
dat <- read_csv("vgsales.csv")
dat
# Out:
# Parsed with column specification:
# cols(
#   Rank = col_double(),
#   Name = col_character(),
#   Platform = col_character(),
#   Year = col_character(),
#   Genre = col_character(),
#   Publisher = col_character(),
#   NA_Sales = col_double(),
#   EU_Sales = col_double(),
#   JP_Sales = col_double(),
#   Other_Sales = col_double(),
#   Global_Sales = col_double()
# )
#       Rank  Name
# 1      1    Wii Sports
# 2      2    Super Mario Bros.
# 3      3    Mario Kart Wii
# 4      4    Wii Sports Resort
# 5      5    Pokemon Red/Pokemon Blue
# 6      6    Tetris
# 7      7    New Super Mario Bros.
# 8      8    Wii Play
# 9      9    New Super Mario Bros. Wii
# 10    10    Duck Hunt
# 11    11    Nintendogs
# 12    12    Mario Kart DS
# 13    13    Pokemon Gold/Pokemon Silver
# 14    14    Wii Fit
# 15    15    Wii Fit Plus
# 16    16    Kinect Adventures!
# 17    17    Grand Theft Auto V
# 18    18    Grand Theft Auto: San Andreas
# 19    19    Super Mario World
# 20    20    Brain Age: Train Your Brain in Minutes a Day
# 21    21    Pokemon Diamond/Pokemon Pearl
# 22    22    Super Mario Land
# 23    23    Super Mario Bros. 3
# 24    24    Grand Theft Auto V
# 25    25    Grand Theft Auto: Vice City
# 26    26    Pokemon Ruby/Pokemon Sapphire
# 27    27    Pokemon Black/Pokemon White
# 28    28    Brain Age 2: More Training in Minutes a Day
# 29    29    Gran Turismo 3: A-Spec
# 30    30    Call of Duty: Modern Warfare 3
# ⋮     ⋮     ⋮
# 16569 16571 XI Coliseum
# 16570 16572 Resident Evil 4 HD
# 16571 16573 Farming 2017 - The Simulation
# 16572 16574 Grisaia no Kajitsu: La Fruit de la Grisaia
# 16573 16575 Scarlett: Nichijou no Kyoukaisen
# 16574 16576 Mini Desktop Racing
# 16575 16577 Yattaman Wii: BikkuriDokkiri Machine de Mou Race da Koron
# 16576 16578 Neo Angelique Special
# 16577 16579 Rugby Challenge 3
# 16578 16580 Damnation
# 16579 16581 Outdoors Unleashed: Africa 3D
# 16580 16582 PGA European Tour
# 16581 16583 Real Rode
# 16582 16584 Fit & Fun
# 16583 16585 Planet Monsters
# 16584 16586 Carmageddon 64
# 16585 16587 Bust-A-Move 3000
# 16586 16588 Breach
# 16587 16589 Secret Files 2: Puritas Cordis
# 16588 16590 Mezase!! Tsuri Master DS
# 16589 16591 Mega Brain Boost
# 16590 16592 Chou Ezaru wa Akai Hana: Koi wa Tsuki ni Shirube Kareru
# 16591 16593 Eiyuu Densetsu: Sora no Kiseki Material Collection Portable
# 16592 16594 Myst IV: Revelation
# 16593 16595 Plushees
# 16594 16596 Woody Woodpecker in Crazy Castle 5
# 16595 16597 Men in Black II: Alien Escape
# 16596 16598 SCORE International Baja 1000: The Official Game
# 16597 16599 Know How 2
# 16598 16600 Spirits & Spells
#       Platform Year Genre        Publisher                   NA_Sales EU_Sales
# 1     Wii      2006 Sports       Nintendo                    41.49    29.02
# 2     NES      1985 Platform     Nintendo                    29.08     3.58
# 3     Wii      2008 Racing       Nintendo                    15.85    12.88
# 16590 PSV      2016 Action       dramatic create             0.00     0.00
# 16591 PSP      2007 Role-Playing Falcom Corporation          0.00     0.00
# 16592 PC       2004 Adventure    Ubisoft                     0.01     0.00
# 16593 DS       2008 Simulation   Destineer                   0.01     0.00
# 16594 GBA      2002 Platform     Kemco                       0.01     0.00
# 16595 GC       2003 Shooter      Infogrames                  0.01     0.00
# 16596 PS2      2008 Racing       Activision                  0.00     0.00
# 16597 DS       2010 Puzzle       7G//AMES                    0.00     0.01
# 16598 GBA      2003 Platform     Wanadoo                     0.01     0.00
#       JP_Sales Other_Sales Global_Sales
# 1      3.77     8.46       82.74
# 2      6.81     0.77       40.24
# 3      3.79     3.31       35.82
# 4      3.28     2.96       33.00
# 5     10.22     1.00       31.37
# 6      4.22     0.58       30.26
# 7      6.50     2.90       30.01
# 8      2.93     2.85       29.02
# 9      4.70     2.26       28.62
# 10     0.28     0.47       28.31
# 11     1.93     2.75       24.76
# 12     4.13     1.92       23.42
# 13     7.20     0.71       23.10
# 14     3.60     2.15       22.72
# 15     2.53     1.79       22.00
# 16     0.24     1.67       21.82
# 17     0.97     4.14       21.40
# 18     0.41    10.57       20.81
# 19     3.54     0.55       20.61
# 20     4.16     2.05       20.22
# 21     6.04     1.37       18.36
# 22     4.18     0.42       18.14
# 23     3.84     0.46       17.28
# 24     0.06     1.38       16.38
# 25     0.47     1.78       16.15
# 26     5.38     0.50       15.85
# 27     5.65     0.82       15.32
# 28     5.32     1.18       15.30
# 29     1.87     1.16       14.98
# 30     0.13     1.32       14.76
# ⋮     ⋮        ⋮           ⋮
# 16569 0.01     0           0.01
# 16570 0.00     0           0.01
# 16571 0.00     0           0.01
# 16572 0.01     0           0.01
# 16573 0.01     0           0.01
# 16574 0.00     0           0.01
# 16575 0.01     0           0.01
# 16576 0.01     0           0.01
# 16577 0.00     0           0.01
# 16578 0.00     0           0.01
# 16579 0.00     0           0.01
# 16580 0.00     0           0.01
# 16581 0.01     0           0.01
# 16582 0.00     0           0.01
# 16583 0.00     0           0.01
# 16584 0.00     0           0.01
# 16585 0.00     0           0.01
# 16586 0.00     0           0.01
# 16587 0.00     0           0.01
# 16588 0.01     0           0.01
# 16589 0.00     0           0.01
# 16590 0.01     0           0.01
# 16591 0.01     0           0.01
# 16592 0.00     0           0.01
# 16593 0.00     0           0.01
# 16594 0.00     0           0.01
# 16595 0.00     0           0.01
# 16596 0.00     0           0.01
# 16597 0.00     0           0.01
# 16598 0.00     0           0.01

# %%
top_genre <- dat %>%
    group_by(Genre) %>%
    summarise(n=n()) %>%
    head(6)
top_genre

#omit Misc, summarize the top 5 genre global sales
top_5_genre <- dat %>%
    filter(Genre %in% 
             c("Action", "Adventure", "Fighting", "Platform", "Puzzle"))%>%
    group_by(Year,Genre)%>%
    summarize(total_sales = sum(Global_Sales))
    
top_5_genre
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   Genre     n
# 1 Action    3316
# 2 Adventure 1286
# 3 Fighting   848
# 4 Misc      1739
# 5 Platform   886
# 6 Puzzle     582
# `summarise()` regrouping output by 'Year' (override with `.groups` argument)
#     Year Genre     total_sales
# 1   1980 Action     0.34
# 2   1980 Fighting   0.77
# 3   1981 Action    14.84
# 4   1981 Platform   6.93
# 5   1981 Puzzle     2.24
# 6   1982 Action     6.52
# 7   1982 Platform   5.03
# 8   1982 Puzzle    10.03
# 9   1983 Action     2.86
# 10  1983 Adventure  0.40
# 11  1983 Platform   6.93
# 12  1983 Puzzle     0.78
# 13  1984 Action     1.85
# 14  1984 Platform   0.69
# 15  1984 Puzzle     3.14
# 16  1985 Action     3.52
# 17  1985 Fighting   1.05
# 18  1985 Platform  43.17
# 19  1985 Puzzle     3.21
# 20  1986 Action    13.74
# 21  1986 Platform   9.39
# 22  1987 Action     1.12
# 23  1987 Adventure  4.38
# 24  1987 Fighting   5.42
# 25  1987 Platform   1.74
# 26  1988 Action     1.75
# 27  1988 Platform  27.73
# 28  1988 Puzzle     5.58
# 29  1989 Action     4.64
# 30  1989 Platform  20.66
# ⋮   ⋮    ⋮         ⋮
# 140 2012 Action    122.04
# 141 2012 Adventure   5.99
# 142 2012 Fighting    9.51
# 143 2012 Platform   18.55
# 144 2012 Puzzle      1.76
# 145 2013 Action    125.22
# 146 2013 Adventure   6.61
# 147 2013 Fighting    7.21
# 148 2013 Platform   25.12
# 149 2013 Puzzle      0.99
# 150 2014 Action     99.02
# 151 2014 Adventure   6.06
# 152 2014 Fighting   16.15
# 153 2014 Platform    8.89
# 154 2014 Puzzle      1.50
# 155 2015 Action     70.70
# 156 2015 Adventure   8.03
# 157 2015 Fighting    7.78
# 158 2015 Platform    6.05
# 159 2015 Puzzle      0.70
# 160 2016 Action     19.91
# 161 2016 Adventure   1.81
# 162 2016 Fighting    3.86
# 163 2016 Platform    2.07
# 164 2017 Action      0.01
# 165 N/A  Action     28.30
# 166 N/A  Adventure   4.24
# 167 N/A  Fighting    4.86
# 168 N/A  Platform    2.22
# 169 N/A  Puzzle      2.73

# %%
#top 5 gaming platform, head the top 5, most platforms are quite ancient,need to 
#omit those that are currently not featuring
ancient_top_platform <- dat %>%
  group_by(Platform) %>%
  summarise(n=n()) %>%
  arrange(desc(n))%>%
  head(11)
ancient_top_platform

#omit DS, PS2,PS3,PSP(Playstation portable), one potential fault with this
#dataset, newest platforms like switch and PS4 and PS5 are included
#chose, Wii, X360, PS2, PS3, PC
#XB(not really sure difference btw XB and X360), need to investigate
top_5_platform <- dat %>%
  filter(Platform %in% 
           c("Wii", "X360", "PS2", "PC", "PS3"))%>%
  group_by(Year,Platform)%>%
  summarize(total_sales = sum(Global_Sales))

top_5_platform
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#    Platform n
# 1  DS       2163
# 2  PS2      2161
# 3  PS3      1329
# 4  Wii      1325
# 5  X360     1265
# 6  PSP      1213
# 7  PS       1196
# 8  PC        960
# 9  XB        824
# 10 GBA       822
# 11 GC        556
# `summarise()` regrouping output by 'Year' (override with `.groups` argument)
#    Year Platform total_sales
# 1  1985 PC         0.03
# 2  1988 PC         0.03
# 3  1992 PC         3.02
# 4  1994 PC        12.85
# 5  1995 PC         4.23
# 6  1996 PC        10.59
# 7  1997 PC        11.26
# 8  1998 PC         3.28
# 9  1999 PC         4.75
# 10 2000 PC         4.68
# 11 2000 PS2       39.11
# 12 2001 PC         5.51
# 13 2001 PS2      166.43
# 14 2002 PC         8.60
# 15 2002 PS2      205.40
# 16 2003 PC         8.96
# 17 2003 PS2      184.29
# 18 2004 PC        10.46
# 19 2004 PS2      211.78
# 20 2005 PC         4.47
# 21 2005 PS2      160.65
# 22 2005 X360       8.32
# 23 2006 PC         2.97
# 24 2006 PS2      103.42
# 25 2006 PS3       21.07
# 26 2006 Wii      137.91
# 27 2006 X360      51.88
# 28 2007 PC         9.40
# 29 2007 PS2       76.00
# 30 2007 PS3       73.81
# ⋮  ⋮    ⋮        ⋮
# 47 2010 X360     171.05
# 48 2011 PC        35.25
# 49 2011 PS2        0.47
# 50 2011 PS3      159.37
# 51 2011 Wii       62.41
# 52 2011 X360     145.12
# 53 2012 PC        23.53
# 54 2012 PS3      109.49
# 55 2012 Wii       22.77
# 56 2012 X360     100.88
# 57 2013 PC        12.83
# 58 2013 PS3      117.39
# 59 2013 Wii        9.36
# 60 2013 X360      89.61
# 61 2014 PC        13.39
# 62 2014 PS3       50.96
# 63 2014 Wii        4.44
# 64 2014 X360      36.42
# 65 2015 PC         8.07
# 66 2015 PS3       18.22
# 67 2015 Wii        1.55
# 68 2015 X360      13.05
# 69 2016 PC         2.60
# 70 2016 PS3        2.59
# 71 2016 X360       0.83
# 72 N/A  PC         3.77
# 73 N/A  PS2       22.18
# 74 N/A  PS3        8.49
# 75 N/A  Wii       16.90
# 76 N/A  X360      10.35

# %%
#plot top 5 platforms' global sales vs yr
options(repr.plot.width = 15, repr.plot.height = 6)
top_5_platform_plot <- top_5_platform %>%
  ggplot(aes(x = Year, y = total_sales, colour = Platform))+
  geom_point()+
  labs(x = "Year of the game's release",
       y = "Total Sales (in millions USD)", 
       colour = "Platform of the game",
       title = "Sales for the top 5 gaming platform")+
  theme(axis.text.x = element_text(angle = 60, vjust = 0.5, hjust=0.5), 
        text = element_text(size = 10))+
  theme(plot.title = element_text(hjust = 0.5))
top_5_platform_plot

#top 5 publisher's sum of all sales 
top_publisher <- dat %>%
  group_by(Publisher)%>%
  summarize(sum_NA_Salles = sum(NA_Sales), 
            sum_EU_Sales = sum(EU_Sales),
            sum_JP_Sales = sum(JP_Sales),
            sum_Global_Sales = sum(Global_Sales))%>%
  arrange(desc(sum_Global_Sales))%>%
  head(10)

top_publisher
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#    Publisher                    sum_NA_Salles sum_EU_Sales sum_JP_Sales
# 1  Nintendo                     816.87        418.74       455.42
# 2  Electronic Arts              595.07        371.27        14.04
# 3  Activision                   429.70        215.53         6.54
# 4  Sony Computer Entertainment  265.22        187.72        74.10
# 5  Ubisoft                      253.43        163.32         7.50
# 6  Take-Two Interactive         220.49        118.14         5.83
# 7  THQ                          208.77         94.73         5.01
# 8  Konami Digital Entertainment  92.16         69.69        91.30
# 9  Sega                         109.40         82.00        57.03
# 10 Namco Bandai Games            69.52         42.63       127.07
#    sum_Global_Sales
# 1  1786.56
# 2  1110.32
# 3   727.46
# 4   607.50
# 5   474.72
# 6   399.54
# 7   340.77
# 8   283.64
# 9   272.99
# 10  254.09
# plot without title

# %%
options(repr.plot.width = 15, repr.plot.height = 6)
top_publisher_plot <- top_5_platform %>%
  ggplot(aes(x = Platform, y = total_sales))+
  geom_histogram()+
  labs(x = "Game Publisher",
       y = "Total Sales (in millions USD)",
       title = "Sales for the top 5 gaming platform")+
  theme(axis.text.x = element_text(angle = 60, vjust = 0.5, hjust=0.5), 
        text = element_text(size = 10))+
  theme(plot.title = element_text(hjust = 0.5))
top_publisher_plot
#correlation with total sales with regional sales in relation with genres
#help figure out the predictors
# Out:
# ERROR while rich displaying an object: Error: stat_bin() can only have an x or y aesthetic.
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_text.default(obj)
# 9. paste(capture.output(print(obj)), collapse = "\n")
# 10. capture.output(print(obj))
# 11. evalVis(expr)
# 12. withVisible(eval(expr, pf))
# 13. eval(expr, pf)
# 14. eval(expr, pf)
# 15. print(obj)
# 16. print.ggplot(obj)
# 17. ggplot_build(x)
# 18. ggplot_build.ggplot(x)
# 19. by_layer(function(l, d) l$compute_statistic(d, layout))
# 20. f(l = layers[[i]], d = data[[i]])
# 21. l$compute_statistic(d, layout)
# 22. f(..., self = self)
# 23. self$stat$setup_params(data, self$stat_params)
# 24. f(...)
# 25. abort("stat_bin() can only have an x or y aesthetic.")
# 26. signal_abort(cnd)
# plot without title

# %%
dat2<-dat%>%
  filter(Genre== "Action")%>%
  filter(Platform %in% 
           c("Wii", "X360", "PS2", "PC", "PS3"))

dat2
# Out:
#      Rank  Name                                            Platform Year Genre
# 1     17   Grand Theft Auto V                              PS3      2013 Action
# 2     18   Grand Theft Auto: San Andreas                   PS2      2004 Action
# 3     24   Grand Theft Auto V                              X360     2013 Action
# 4     25   Grand Theft Auto: Vice City                     PS2      2002 Action
# 5     39   Grand Theft Auto III                            PS2      2001 Action
# 6     52   Grand Theft Auto IV                             X360     2008 Action
# 7     57   Grand Theft Auto IV                             PS3      2008 Action
# 8     83   FIFA Soccer 13                                  PS3      2012 Action
# 9    101   The Legend of Zelda: Twilight Princess          Wii      2006 Action
# 10   116   Uncharted 3: Drake's Deception                  PS3      2011 Action
# 11   120   Uncharted 2: Among Thieves                      PS3      2009 Action
# 12   124   Red Dead Redemption                             PS3      2010 Action
# 13   129   Assassin's Creed III                            PS3      2012 Action
# 14   135   Red Dead Redemption                             X360     2010 Action
# 15   143   Metal Gear Solid 2: Sons of Liberty             PS2      2001 Action
# 16   145   Metal Gear Solid 4: Guns of the Patriots        PS3      2008 Action
# 17   147   The Last of Us                                  PS3      2013 Action
# 18   151   LEGO Star Wars: The Complete Saga               Wii      2007 Action
# 19   157   Assassin's Creed II                             PS3      2009 Action
# 20   160   Batman: Arkham City                             PS3      2011 Action
# 21   173   Assassin's Creed III                            X360     2012 Action
# 22   177   Assassin's Creed II                             X360     2009 Action
# 23   186   FIFA Soccer 13                                  X360     2012 Action
# 24   197   Resident Evil 5                                 PS3      2009 Action
# 25   211   Uncharted: Drake's Fortune                      PS3      2007 Action
# 26   217   God of War III                                  PS3      2010 Action
# 27   223   Batman: Arkham City                             X360     2011 Action
# 1427 0           0.02
# 1428 0           0.01
# 1429 0           0.01
# 1430 0           0.01
# 1431 0           0.01
# 1432 0           0.01
# 1433 0           0.01
# 1434 0           0.01
# 1435 0           0.01
# 1436 0           0.01
# 1437 0           0.01
# 1438 0           0.01
# 1439 0           0.01
# 1440 0           0.01
# 1441 0           0.01
# 1442 0           0.01
# 1443 0           0.01
# 1444 0           0.01
# 1445 0           0.01
# 1446 0           0.01
# 1447 0           0.01
# 1448 0           0.01
# 1449 0           0.01
# 1450 0           0.01
# 1451 0           0.01
# 1452 0           0.01
# 1453 0           0.01
# 1454 0           0.01
# 1455 0           0.01

# %%
dat_top_10_games_in_Japan_and_NA<-dat2%>%
group_by(JP_Sales)%>%
head(10)
dat_top_10_games_in_Japan_and_NA
# Out:
#    Rank Name                                   Platform Year Genre
# 1   17  Grand Theft Auto V                     PS3      2013 Action
# 2   18  Grand Theft Auto: San Andreas          PS2      2004 Action
# 3   24  Grand Theft Auto V                     X360     2013 Action
# 4   25  Grand Theft Auto: Vice City            PS2      2002 Action
# 5   39  Grand Theft Auto III                   PS2      2001 Action
# 6   52  Grand Theft Auto IV                    X360     2008 Action
# 7   57  Grand Theft Auto IV                    PS3      2008 Action
# 8   83  FIFA Soccer 13                         PS3      2012 Action
# 9  101  The Legend of Zelda: Twilight Princess Wii      2006 Action
# 10 116  Uncharted 3: Drake's Deception         PS3      2011 Action
#    Publisher                   NA_Sales EU_Sales JP_Sales Other_Sales
# 1  Take-Two Interactive        7.01     9.27     0.97      4.14
# 2  Take-Two Interactive        9.43     0.40     0.41     10.57
# 3  Take-Two Interactive        9.63     5.31     0.06      1.38
# 4  Take-Two Interactive        8.41     5.49     0.47      1.78
# 5  Take-Two Interactive        6.99     4.51     0.30      1.30
# 6  Take-Two Interactive        6.76     3.10     0.14      1.03
# 7  Take-Two Interactive        4.76     3.76     0.44      1.62
# 8  Electronic Arts             1.06     5.05     0.13      2.01
# 9  Nintendo                    3.83     2.19     0.60      0.70
# 10 Sony Computer Entertainment 2.77     2.80     0.19      1.06
#    Global_Sales
# 1  21.40
# 2  20.81
# 3  16.38
# 4  16.15
# 5  13.10
# 6  11.02
# 7  10.57
# 8   8.24
# 9   7.31
# 10  6.83

# %%
top10_plot<-ggplot(dat_top_10_games_in_Japan_and_NA)+
# Out:
# Error in parse(text = x, srcfile = src): <text>:3:0: unexpected end of input
# 1: top10_plot<-ggplot(dat_top_10_games_in_Japan_and_NA)+
# 2:
#   ^
# Traceback:

# %%
vg_genre <- vg_train %>%
  group_by(Genre) %>%
  summarise(n=n())%>%
  arrange(desc(n))

vg_genre
# Out:
# Error in eval(lhs, parent, parent): object 'vg_train' not found
# Traceback:
#
# 1. vg_train %>% group_by(Genre) %>% summarise(n = n()) %>% arrange(desc(n))
# 2. eval(lhs, parent, parent)
# 3. eval(lhs, parent, parent)

# %%
vg_##<- vg_train_##%>% 
  select(-(Rank:Publisher))

vg_##

sales_cor_## <- round(cor(vg_##),2)%>%
  as.matrix()
# Out:
# Error in eval(expr, envir, enclos): object 'vg_' not found
# Traceback:
